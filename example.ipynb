# %%
from data import load_numpy_image
from processing import gaussian_filter_transform, mean_filter_transform, sharpen_transform
from visualization import save_image

# %%
image = './images/blurry_street.jpg'

# %%
import matplotlib.pyplot as plt

# %%
input_image = load_numpy_image(image)

# %%
plt.imshow(input_image)

# %%
output_image = mean_filter_transform(input_image, (11, 11)) / 255

# %%
plt.imshow(output_image)

# %%
output_image = gaussian_filter_transform(input_image, (11, 11), sigma=0.1) / 255

# %%
plt.imshow(output_image)

# %%
output_image = sharpen_transform(input_image, (11, 11), sigma=10.0) / 255

# %%
plt.imshow(output_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
